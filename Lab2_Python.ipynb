# %%
# How do you ask if a file exists?

import glob

glob.glob('/Users/cabweebwub/Desktop/DevCellBakeOff.png')
#If the file exists it'll return it, if not it will return a blank
# Out:
# ['/Users/cabweebwub/Desktop/DevCellBakeOff.png']

# %%
# How to you ask if a file is a directory?

os.path.isdir('/Users/cabweebwub/Desktop/')
# Out:
# True

# %%
# How do you remove (delete) a file?
os.remove('/Users/cabweebwub/Desktop/test.rtf')

# %%
# How do you get the size of a file?
os.path.getsize('/Users/cabweebwub/Desktop/DevCellBakeOff_Flyer.pdf')
# Out:
# 325775

# %%
# How do you get all the file names matching a pattern?
glob.glob('/Users/cabweebwub/Desktop/Dev*')
# Out:
# ['/Users/cabweebwub/Desktop/DevCellBakeOff.png',
#  '/Users/cabweebwub/Desktop/DevCellBakeOff_Flyer.docx',
#  '/Users/cabweebwub/Desktop/DevCellBakeOff_Flyer.pdf',
#  '/Users/cabweebwub/Desktop/DevCellHappyHour_Flyer.docx',
#  '/Users/cabweebwub/Desktop/DevCellHappyHour_Flyer.pdf']

# %%
# How do you get all the file names matching a pattern recursively?
glob.glob('/Users/cabweebwub/Desktop/Dev*', recursive=True)
# Out:
# ['/Users/cabweebwub/Desktop/DevCellBakeOff.png',
#  '/Users/cabweebwub/Desktop/DevCellBakeOff_Flyer.docx',
#  '/Users/cabweebwub/Desktop/DevCellBakeOff_Flyer.pdf',
#  '/Users/cabweebwub/Desktop/DevCellHappyHour_Flyer.docx',
#  '/Users/cabweebwub/Desktop/DevCellHappyHour_Flyer.pdf']

# %%
# How do you get an iterator to all files matching a pattern, as opposed to returning a potentially huge list?
glob.iglob('/Users/cabweebwub/Desktop/', recursive=True)
# Out:
# <generator object _iglob at 0x11277f3b8>

# %%
# How do you open gzip-compressed files for reading and for writing
import gzip
gzip.open('/Users/cabweebwub/Desktop/lab2data.tar.gz')
# Out:
# <gzip _io.BufferedReader name='/Users/cabweebwub/Desktop/lab2data.tar.gz' 0x1127b1710>

# %%
# Generate a list of those output files that were not created. Do it in R and in Python. Which is easier/less annoying?
input = glob.glob('/Users/cabweebwub/Desktop/Lab2/lab2data/data/datafile*')
output = glob.glob('/Users/cabweebwub/Desktop/Lab2/lab2data/output/outfile*')

# %%
df = pd.DataFrame({"input_files" : input})
df = df['input_files'].apply(''.join)
in_files = df.str.split('.',n=-1,expand=True)
df2 = pd.DataFrame({"output_files" : output})
df2 = df2['output_files'].apply(''.join)
out_files = df2.str.split('.',n=-1,expand=True)

# %%
files = pd.concat([in_files[1]+in_files[2],out_files[1]+out_files[2]], axis=1)
files['Does the Input Have an Ouput?'] = files[0].isin(files[1])
final = files.iloc[:,[0,2]]
final
# Out:
#       0  Does the Input Have an Ouput?
# 0    1a                           True
# 1    1b                           True
# 2   10a                           True
# 3   10b                          False
# 4   11a                          False
# 5   11b                          False
# 6   12a                          False
# 7   12b                          False
# 8   13a                           True
# 9   13b                          False
# 10  14a                          False
# 11  14b                          False
# 12  15a                          False
# 13  15b                           True
# 14  16a                           True
# 15  16b                          False
# 16  17a                          False
# 17  17b                          False
# 18  18a                          False
# 19  18b                          False
# 20  19a                           True
# 21  19b                          False
# 22   2a                          False
# ...
